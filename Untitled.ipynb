# %% [markdown]
# # diagnose pertlim

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from geocat.viz import util as gvutil
import datetime
import cf_units as cf
import dask

# %%
import pandas as pd

# %%
import glob

# %%
casename0 = 'f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00'
casename1 = 'f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02'
casename2 = 'f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03'

# %%
dir = '/glade/derecho/scratch/patc/archive/'

# %%
filename0 = f"{dir}{casename0}/atm/hist/{casename0}.cam.h2a*.nc"

ds = xr.open_mfdataset(filename0)
glob.glob(filename0)
# Out:
# ['/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00.cam.h2a.2021-02-12-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00.cam.h2a.2021-02-09-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00.cam.h2a.2021-02-10-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00.cam.h2a.2021-02-11-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_00.cam.h2a.2021-02-08-03600.nc']

# %%
filename1 = f"{dir}{casename1}/atm/hist/{casename1}.cam.h2a*.nc"
ds1 = xr.open_mfdataset(filename1)
glob.glob(filename1)
# Out:
# ['/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02.cam.h2a.2021-02-12-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02.cam.h2a.2021-02-09-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02.cam.h2a.2021-02-08-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02.cam.h2a.2021-02-10-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_02.cam.h2a.2021-02-11-03600.nc']

# %%
filename2 = f"{dir}{casename2}/atm/hist/{casename2}.cam.h2a*.nc"
ds2 = xr.open_mfdataset(filename2)
glob.glob(filename2)
# Out:
# ['/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03.cam.h2a.2021-02-09-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03.cam.h2a.2021-02-08-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03.cam.h2a.2021-02-11-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03.cam.h2a.2021-02-12-03600.nc',
#  '/glade/derecho/scratch/patc/archive/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03/atm/hist/f.e23b17.FLTHIST_mpasa60.S2S.L58_FEB08_TEST_03.cam.h2a.2021-02-10-03600.nc']

# %%
(ds.PSL - ds1.PSL).max().compute()
# Out:
# <xarray.DataArray 'PSL' ()>
# array(0., dtype=float32)

# %%
ds.SST.mean('ncol')[0:3].compute()
#ds2.SST.mean('ncol')[0:3].plot()
# Out:
# <xarray.DataArray 'SST' (time: 3)>
# array([286.5804 , 286.58057, 286.58072], dtype=float32)
# Coordinates:
#   * time     (time) object 2021-02-08 00:30:00 ... 2021-02-08 02:30:00

# %%
ds2.SST.mean('ncol')[0:3].compute()
# Out:
# <xarray.DataArray 'SST' (time: 3)>
# array([286.5804 , 286.58057, 286.58072], dtype=float32)
# Coordinates:
#   * time     (time) object 2021-02-08 00:30:00 ... 2021-02-08 02:30:00

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 120, ncol: 163842, lev: 58, ilev: 59,
#                    trop_cld_lev: 58, nbnd: 2)
# Coordinates:
#   * lev           (lev) float64 4.112e+04 3.687e+04 3.323e+04 ... 106.2 35.0
#   * ilev          (ilev) float64 4.343e+04 3.88e+04 3.494e+04 ... 142.4 70.0 0.0
#   * trop_cld_lev  (trop_cld_lev) float64 4.112e+04 3.687e+04 ... 106.2 35.0
#   * time          (time) object 2021-02-08 00:30:00 ... 2021-02-12 23:30:00
# Dimensions without coordinates: ncol, nbnd
# Data variables: (12/57)
#     lat           (time, ncol) float64 dask.array<chunksize=(24, 163842), meta=np.ndarray>
#     lon           (time, ncol) float64 dask.array<chunksize=(24, 163842), meta=np.ndarray>
#     areawt        (time, ncol) float64 dask.array<chunksize=(24, 163842), meta=np.ndarray>
#     area          (time, ncol) float64 dask.array<chunksize=(24, 163842), meta=np.ndarray>
#     date          (time) int32 dask.array<chunksize=(24,), meta=np.ndarray>
# ...
